# %%
from classify import classify_text as classifier
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from graph_rag import GraphRAG
from tqdm import tqdm
import pandas as pd
import evaluate

# %%
# Load the dataset
df = pd.read_excel("dataset.xlsx")

graph_rag = GraphRAG(model_name="gpt-4o-mini")

# Function to generate answers using GraphRAG
def generate_answer(question):
    """Generate answer using the GraphRAG system"""
    try:
        # Try to classify the question if classifier is available
        label = None
        if classifier is not None:
            try:
                label = classifier(question)
                print(f"Question classified as: {label}")
            except Exception as e:
                print(f"Classification failed: {e}")
                label = None
        
        # Generate response using GraphRAG
        result = graph_rag.generate_response(question, label)
        return result["response"]
    except Exception as e:
        print(f"Error generating answer for question: {question}")
        print(f"Error: {e}")
        return "Error generating answer"

# Generate answers for all questions in the dataset
print("Generating answers using GraphRAG...")
tqdm.pandas(desc="Generating Answers")
df['generated_answer'] = df['question'].progress_apply(generate_answer)

# Initialize the evaluation metrics from Hugging Face
bleu = evaluate.load("bleu")
rouge = evaluate.load("rouge")

# --- LLM as a Judge ---
# This section uses a simple LLM judge implementation
# You can enhance this by using a more sophisticated LLM for judging

def llm_judge(question, generated_answer, ground_truth):
    """
    LLM Judge function to evaluate generated answers using actual LLM calls
    """
    try:
        # Create a more sophisticated prompt template
        template = """
        You are an expert evaluator. Your task is to evaluate a generated answer based on a given question and a ground truth answer.
        
        Question: {question}
        Ground Truth Answer: {ground_truth}
        Generated Answer: {generated_answer}
        
        Please evaluate the generated answer for correctness, relevance, and completeness based on the ground truth.
        Respond with a single integer score:
        1 - The generated answer is correct and aligns well with the ground truth.
        0 - The generated answer is incorrect or does not align with the ground truth.
        
        Only respond with the number (0 or 1), no additional text.
        """

        llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
        prompt = ChatPromptTemplate.from_template(template)

        chain = (
            prompt
            | llm
            | StrOutputParser()
        )

        response = chain.invoke({
            "question": question, 
            "ground_truth": ground_truth, 
            "generated_answer": generated_answer
        })
        
        # Extract the numeric score from the response
        import re
        score_match = re.search(r'([01])', response.strip())
        if score_match:
            return int(score_match.group(1))
        else:
            # Fallback to simple string matching if LLM doesn't return expected format
            if generated_answer.lower() in ground_truth.lower() or ground_truth.lower() in generated_answer.lower():
                return 1
            else:
                return 0
                
    except Exception as e:
        print(f"Error in LLM judge: {e}")
        # Fallback to simple string matching
        if generated_answer.lower() in ground_truth.lower() or ground_truth.lower() in generated_answer.lower():
            return 1
        else:
            return 0

# Apply LLM judge to evaluate all generated answers
print("Evaluating answers using LLM Judge...")
df['llm_judge_score'] = df.progress_apply(lambda row: llm_judge(row['question'], row['ground truth'], row['ground_truth']), axis=1)

# --- Calculate Precision, Recall, F1-Score, Accuracy ---
# Based on the LLM Judge scores
true_positives = df['llm_judge_score'].sum()
false_positives = len(df) - true_positives # Simplified for this example

accuracy = true_positives / len(df)
precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) > 0 else 0
recall = true_positives / len(df)
f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

print("\n--- LLM Judge Evaluation ---")
print(f"Total Questions: {len(df)}")
print(f"Correct Answers: {true_positives}")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1_score:.4f}")

# --- BLEU and ROUGE Score Calculation ---
predictions = df['generated_answer'].tolist()
references = [[gt] for gt in df['ground_truth'].tolist()]

print("\nCalculating BLEU and ROUGE scores...")
bleu_results = bleu.compute(predictions=predictions, references=references)
rouge_results = rouge.compute(predictions=predictions, references=references)

print("\n--- BLEU Score ---")
print(f"BLEU Score: {bleu_results['bleu']:.4f}")
print(f"BLEU Precisions: {bleu_results['precisions']}")

print("\n--- ROUGE Score ---")
print(f"ROUGE-1: {rouge_results['rouge1']:.4f}")
print(f"ROUGE-2: {rouge_results['rouge2']:.4f}")
print(f"ROUGE-L: {rouge_results['rougeL']:.4f}")

# Save results to a CSV file for further analysis
df.to_csv('evaluation_results.csv', index=False)
print("\nResults saved to 'evaluation_results.csv'")

# Display sample results
print("\n--- Sample Results ---")
print(df[['Question', 'ground_truth', 'generated_answer', 'llm_judge_score']].head())
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at vinai/phobert-base-v2 and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at vinai/phobert-base-v2 and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Generating answers using GraphRAG...
# Generating Answers:  19%|█▉        | 88/469 [00:00<00:00, 877.04it/s]
# Predicted label: __label__KTX
# Probability: 0.9839826822280884
# Question classified as: KTX
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Xe vô chủ và xe gửi quá thời hạn sẽ được xử lý như thế nào theo quy định của trung tâm PVSV?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__KTX
# Probability: 0.7270471453666687
# Question classified as: KTX
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Thẻ giữ xe và phiếu giữ xe quá hạn có giá trị như thế nào sau mỗi học kỳ?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Hoc_tap_ren_luyen
# Probability: 0.5236092805862427
# Question classified as: Hoc_tap_ren_luyen
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Sinh viên sẽ phải chi trả phí gì khi lấy xe quá thời hạn?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__KTX
# Probability: 0.6500936150550842
# Question classified as: KTX
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Sinh viên có trách nhiệm gì về phí điện, nước hàng tháng?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__KTX
# Probability: 0.7816632986068726
# Question classified as: KTX
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Khi phát hiện hư hỏng đồng hồ đo điện, nước, sinh viên cần làm gì?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__KTX
# Probability: 0.9199792742729187
# Question classified as: KTX
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Sinh viên vi phạm nội quy sẽ bị xử lý kỷ luật như thế nào?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__KTX
# Probability: 0.5356716513633728
# Question classified as: KTX
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Các hoạt động nào khiến sinh viên có thể được khen thưởng?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Khac
# Probability: 0.9980061054229736
# Question classified as: Khac
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Quyết định về mục tiêu giáo dục của trường Đại học Cần Thơ được ban hành vào năm nào?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Khac
# Probability: 0.9976097941398621
# Question classified as: Khac
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Căn cứ nào được sử dụng để ban hành quyết định về mục tiêu giáo dục của trường Đại học Cần Thơ?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Khac
# Probability: 0.7550255656242371
# Question classified as: Khac
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Mục tiêu giáo dục của trường Đại học Cần Thơ được thực hiện theo mục tiêu nào?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Khac
# Probability: 0.6007034182548523
# Question classified as: Khac
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Mục tiêu giáo dục của trường Đại học Cần Thơ bao gồm những nội dung gì?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Tot_nghiep
# Probability: 0.9083696603775024
# Question classified as: Tot_nghiep
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Điều nào quy định về quyền tự chủ của đơn vị sự nghiệp công lập?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Khac
# Probability: 0.9712923169136047
# Question classified as: Khac
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Mục tiêu giáo dục của trường Đại học Cần Thơ nhằm phục vụ nhu cầu gì?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Khac
# Probability: 0.9899212718009949
# Question classified as: Khac
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Theo quyết định, người học tại trường Đại học Cần Thơ cần phát triển những kỹ năng gì?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Hoc_tap_ren_luyen
# Probability: 0.9970526099205017
# Question classified as: Hoc_tap_ren_luyen
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Quyết định nào ban hành quy chế cử sinh viên đi học tập ở nước ngoài?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Hoc_tap_ren_luyen
# Probability: 0.999721109867096
# Question classified as: Hoc_tap_ren_luyen
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Quy chế cử sinh viên đi học tập ở nước ngoài áp dụng cho đối tượng nào?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Dao_tao
# Probability: 0.8172061443328857
# Question classified as: Dao_tao
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Quyết định này có hiệu lực từ học kỳ nào và năm học nào?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Hoc_tap_ren_luyen
# Probability: 0.999923825263977
# Question classified as: Hoc_tap_ren_luyen
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Mục tiêu của quy chế cử sinh viên đi học tập ở nước ngoài là gì?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Hoc_tap_ren_luyen
# Probability: 0.7086398005485535
# Question classified as: Hoc_tap_ren_luyen
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Quy chế này nhằm nâng cao điều gì cho sinh viên?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Dao_tao
# Probability: 0.541896402835846
# Question classified as: Dao_tao
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Ai có trách nhiệm thi hành quyết định này?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Hoc_tap_ren_luyen
# Probability: 0.9687298536300659
# Question classified as: Hoc_tap_ren_luyen
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Quy chế cử sinh viên đi học tập ở nước ngoài được ban hành kèm theo quyết định nào?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Dao_tao
# Probability: 0.9681130647659302
# Question classified as: Dao_tao
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: DELf là gì và ai cấp chứng chỉ này?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Dao_tao
# Probability: 0.9808474183082581
# Question classified as: Dao_tao
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: DALE là chứng chỉ gì và do ai cấp?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Dao_tao
# Probability: 0.9587565064430237
# Question classified as: Dao_tao
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question:
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Điều kiện để sinh viên được xét tốt nghiệp là gì?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Dao_tao
# Probability: 0.9954460263252258
# Question classified as: Dao_tao
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Ai là người thành lập ban quản lý chương trình đào tạo chất lượng cao và chương trình đào tạo tiên tiến?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Dao_tao
# Probability: 0.9982845783233643
# Question classified as: Dao_tao
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Ban quản lý chương trình đào tạo chất lượng cao hoặc ban quản lý chương trình đào tạo tiên tiến do ai làm trưởng ban?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Dao_tao
# ...
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Chứng chỉ TOEIC được cấp bởi tổ chức nào?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Dao_tao
# Probability: 0.9427523612976074
# Question classified as: Dao_tao
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Chứng chỉ nào được cấp bởi tổ chức Cambridge English?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Dao_tao
# Probability: 0.997276782989502
# Question classified as: Dao_tao
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Khung năng lực ngoại ngữ được sử dụng cho Việt Nam có bao nhiêu bậc?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Dao_tao
# Probability: 0.9913740158081055
# Question classified as: Dao_tao
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Chứng chỉ ngoại ngữ tiếng Anh A, B, C được cấp bởi trường nào?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Dao_tao
# Probability: 0.9905604124069214
# Question classified as: Dao_tao
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Chứng chỉ TOEFL có điểm tương đương nào trong khung năng lực ngoại ngữ?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Dao_tao
# Probability: 0.9978633522987366
# Question classified as: Dao_tao
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Điều 28 quy định về điều khoản thi hành trong trường hợp nào?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Dao_tao
# Probability: 0.6310507655143738
# Question classified as: Dao_tao
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Khi các văn bản quy phạm pháp luật được sửa đổi, bổ sung, thay thế, quy định nào sẽ được thực hiện?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Dao_tao
# Probability: 0.7580090761184692
# Question classified as: Dao_tao
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Ai là người chịu trách nhiệm thực hiện quy định này?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Dao_tao
# Probability: 0.5398334264755249
# Question classified as: Dao_tao
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Lãnh đạo các đơn vị và cá nhân có liên quan cần làm gì trong quá trình thực hiện quy định?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__KTX
# Probability: 0.47312623262405396
# Question classified as: KTX
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Cụm từ nào chỉ ra rằng quy định có thể bị sửa đổi?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Hoc_tap_ren_luyen
# Probability: 0.9986581206321716
# Question classified as: Hoc_tap_ren_luyen
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Học bổng khuyến khích học tập được xét áp dụng theo tiêu chí nào?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Khen_thuong_ky_luat
# Probability: 0.998241126537323
# Question classified as: Khen_thuong_ky_luat
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Điều kiện để sinh viên được xét học bổng là gì?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Hoc_tap_ren_luyen
# Probability: 0.9352003931999207
# Question classified as: Hoc_tap_ren_luyen
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Học bổng dành cho sinh viên đi học tập ở nước ngoài do ai quyết định?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Khac
# Probability: 0.3770439326763153
# Question classified as: Khac
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Sinh viên mồ côi cả cha lẫn mẹ thuộc đối tượng nào được hưởng trợ cấp xã hội?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Hoc_tap_ren_luyen
# Probability: 0.8579981923103333
# Question classified as: Hoc_tap_ren_luyen
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Học phí được tính theo tiêu chí nào?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Dao_tao
# Probability: 0.9991004467010498
# Question classified as: Dao_tao
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Sinh viên có thể làm đơn xin nghỉ học tạm thời trong những trường hợp nào?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Dao_tao
# Probability: 0.9894059300422668
# Question classified as: Dao_tao
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Điều kiện nào để sinh viên được chuyển cơ sở đào tạo?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Hoc_tap_ren_luyen
# Probability: 0.5984551310539246
# Question classified as: Hoc_tap_ren_luyen
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Trung tâm thông tin và quản trị mạng có chức năng gì?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Dao_tao
# Probability: 0.8757185339927673
# Question classified as: Dao_tao
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Phòng công tác chính trị tổ chức sự kiện nào?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Hoc_tap_ren_luyen
# Probability: 0.932944655418396
# Question classified as: Hoc_tap_ren_luyen
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Phòng công tác chính trị có hoạt động nào liên quan đến văn nghệ?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Dao_tao
# Probability: 0.5224855542182922
# Question classified as: Dao_tao
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Đội nào được phòng công tác chính trị quản lý?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__KTX
# Probability: 0.5541059374809265
# Question classified as: KTX
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Ai xử lý mật khẩu tài khoản và email SV?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Tot_nghiep
# Probability: 0.7409071326255798
# Question classified as: Tot_nghiep
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Lễ phát bằng tốt nghiệp được tổ chức bởi đơn vị nào?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Hoc_tap_ren_luyen
# Probability: 0.8868268728256226
# Question classified as: Hoc_tap_ren_luyen
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Trung tâm thông tin và quản trị mạng có liên quan đến việc gì?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__KTX
# Probability: 0.9383952021598816
# Question classified as: KTX
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Sinh viên sẽ bị xử lý như thế nào khi vi phạm các quy định về tàng trữ sản phẩm văn hóa đồi trụy?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__KTX
# Probability: 0.922890305519104
# Question classified as: KTX
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Các hành vi nào được coi là vi phạm trong nội dung đã nêu?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__KTX
# Probability: 0.9593914747238159
# Question classified as: KTX
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Việc chứa chấp và che giấu hàng gì là vi phạm?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Khen_thuong_ky_luat
# Probability: 0.5439237952232361
# Question classified as: Khen_thuong_ky_luat
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Hành vi đánh bạc dưới hình thức nào thì bị xử lý?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Hoc_tap_ren_luyen
# Probability: 0.5566973686218262
# Question classified as: Hoc_tap_ren_luyen
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Có những hoạt động nào liên quan đến đánh nhau sẽ bị xử lý?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__Dao_tao
# Probability: 0.4938545823097229
# Question classified as: Dao_tao
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Sinh viên sẽ bị xử lý khi nào theo quy định đã nêu?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Predicted label: __label__KTX
# Probability: 0.9691352844238281
# Question classified as: KTX
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Error generating answer for question: Việc lấy cắp tài sản có liên quan đến hành vi nào khác không?
# Error: [Errno 2] No such file or directory: 'd:/GraphRAG/evaluate/storage/docstore.json'
# Downloading builder script: 5.94kB [00:00, ?B/s]
# Downloading extra modules: 4.07kB [00:00, ?B/s]
# Downloading extra modules: 3.34kB [00:00, ?B/s]
# Downloading builder script: 6.27kB [00:00, ?B/s]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[40], line 35
#      33 # Initialize the evaluation metrics from Hugging Face
#      34 bleu = evaluate.load("bleu")
# ---> 35 rouge = evaluate.load("rouge")
#      37 # --- LLM as a Judge ---
#      38 # This section uses a simple LLM judge implementation
#      39 # You can enhance this by using a more sophisticated LLM for judging
#      41 def llm_judge(question, generated_answer, ground_truth):
#
# File d:\GraphRAG\.venv\Lib\site-packages\evaluate\loading.py:748, in load(path, config_name, module_type, process_id, num_process, cache_dir, experiment_id, keep_in_memory, download_config, download_mode, revision, **init_kwargs)
#     703 """Load a [`~evaluate.EvaluationModule`].
#     704
#     705 Args:
#    (...)    745     ```
#     746 """
#     747 download_mode = DownloadMode(download_mode or DownloadMode.REUSE_DATASET_IF_EXISTS)
# --> 748 evaluation_module = evaluation_module_factory(
#     749     path, module_type=module_type, revision=revision, download_config=download_config, download_mode=download_mode
#     750 )
#     751 evaluation_cls = import_main_class(evaluation_module.module_path)
#     752 evaluation_instance = evaluation_cls(
#     753     config_name=config_name,
#     754     process_id=process_id,
#    (...)    760     **init_kwargs,
#     761 )
#
# File d:\GraphRAG\.venv\Lib\site-packages\evaluate\loading.py:680, in evaluation_module_factory(path, module_type, revision, download_config, download_mode, force_local_path, dynamic_modules_path, **download_kwargs)
#     678                 pass
#     679         if not isinstance(e1, (ConnectionError, FileNotFoundError)):
# --> 680             raise e1 from None
#     681         raise FileNotFoundError(
#     682             f"Couldn't find a module script at {relative_to_absolute_path(combined_path)}. "
#     683             f"Module '{path}' doesn't exist on the Hugging Face Hub either."
#     684         ) from None
#     685 else:
#
# File d:\GraphRAG\.venv\Lib\site-packages\evaluate\loading.py:639, in evaluation_module_factory(path, module_type, revision, download_config, download_mode, force_local_path, dynamic_modules_path, **download_kwargs)
#     631 for current_type in ["metric", "comparison", "measurement"]:
#     632     try:
#     633         return HubEvaluationModuleFactory(
#     634             f"evaluate-{current_type}/{path}",
#     635             revision=revision,
#     636             download_config=download_config,
#     637             download_mode=download_mode,
#     638             dynamic_modules_path=dynamic_modules_path,
# --> 639         ).get_module()
#     640     except ConnectionError:
#     641         pass
#
# File d:\GraphRAG\.venv\Lib\site-packages\evaluate\loading.py:489, in HubEvaluationModuleFactory.get_module(self)
#     486         raise err
#     488 imports = get_imports(local_path)
# --> 489 local_imports = _download_additional_modules(
#     490     name=self.name,
#     491     base_path=hf_hub_url(path=self.name, name="", revision=revision),
#     492     imports=imports,
#     493     download_config=self.download_config,
#     494 )
#     495 # copy the script and the files in an importable directory
#     496 dynamic_modules_path = self.dynamic_modules_path if self.dynamic_modules_path else init_dynamic_modules()
#
# File d:\GraphRAG\.venv\Lib\site-packages\evaluate\loading.py:265, in _download_additional_modules(name, base_path, imports, download_config)
#     263         needs_to_be_installed.add((library_import_name, library_import_path))
#     264 if needs_to_be_installed:
# --> 265     raise ImportError(
#     266         f"To be able to use {name}, you need to install the following dependencies"
#     267         f"{[lib_name for lib_name, lib_path in needs_to_be_installed]} using 'pip install "
#     268         f"{' '.join([lib_path for lib_name, lib_path in needs_to_be_installed])}' for instance'"
#     269     )
#     270 return local_imports
#
# ImportError: To be able to use evaluate-metric/rouge, you need to install the following dependencies['absl', 'rouge_score'] using 'pip install # Here to have a nice missing dependency error message early on rouge_score' for instance'
